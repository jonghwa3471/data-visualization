# %%
import pandas as pd
daily_df = pd.read_csv("data/daily_report.csv")
daily_df["Country_Region"]
# Out:
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
#              ...
# 3974           Ukraine
# 3975             Nauru
# 3976       New Zealand
# 3977            Tuvalu
# 3978    United Kingdom
# Name: Country_Region, Length: 3979, dtype: str
